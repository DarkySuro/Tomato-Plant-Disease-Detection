# %% [markdown]
# imports

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from PIL import Image
import random

# %% [markdown]
# Getting one sample image per class

# %%
dataset_path = Path("../dataset/raw")

classes = sorted(
    [folder for folder in dataset_path.iterdir() if folder.is_dir()]
)

fig, axes = plt.subplots(
    nrows=2,
    ncols=5,
    figsize=(18, 8)
)

axes = axes.flatten()

for ax, class_folder in zip(axes, classes):

    images = list(class_folder.glob("*.jpg"))

    sample_image = random.choice(images)

    img = Image.open(sample_image)

    ax.imshow(img)

    class_name = class_folder.name

    ax.set_title(
        class_name,
        fontsize=12
    )

    ax.axis("off")

plt.tight_layout()

plt.savefig(
    "../screenshots/dataset/sample_images_all_classes.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
